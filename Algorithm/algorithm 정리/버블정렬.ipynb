# %% [markdown]
# ### 버블 정렬(Bubble Sort)
# > 인접한 두 개의 원소를 비교하며 자리를 계속 교환하는 방식
#
# - 첫 번째 원소부터 인접한 원소끼리 계속 자리를 교환하면서 맨 마지막 자리까지 이동
# - 한 단계가 끝나면 가장 큰 원소가 마지막 자리로 정렬됨
#
# > 시간 복잡도 : O(n**2)

# %%
# 버블정렬 기본(오름차순)
N = 6
arr = [7, 2, 5, 3, 1, 4]

for i in range(N-1, 0, -1):   # for i : N-1 -> 1, 정렬할 구간의 마지막 원소
    for j in range(i):   # for j : 0 -> i-1 , j는 비교할 두 원소 중 왼쪽의 인덱스
        if arr[j] > arr[j+1]:  # 오름차순은 큰 수를 오른쪽으로
            arr[j], arr[j+1] = arr[j+1], arr[j]  # 만약 왼쪽 인덱스가 오른쪽 인덱스의 값보다 크다면 자리를 바꿈

print(*arr)  # 언패킹으로 리스트 제거
# Out:
# 1 2 3 4 5 7

# %%
# 버블정렬 내림차순
N = 6
arr = [7, 2, 5, 3, 1, 4]

def dec(arr, N):
    for i in range(N-1, 0, -1):   # for i : N-1 -> 1, 정렬할 구간의 마지막 원소
        for j in range(i):   # for j : 0 -> i-1 , j는 비교할 두 원소 중 왼쪽의 인덱스
            if arr[j] < arr[j+1]:  # 내림차순은 작은 수를 오른쪽으로
                arr[j], arr[j+1] = arr[j+1], arr[j]

dec(arr, N)   # 함수 호출
print(arr)
# Out:
# [7, 5, 4, 3, 2, 1]
